# %%
import pandas as pd

# %%
dataframe = pd.DataFrame([{"height" : 1, "weight" : 23, "age" : 24, "city" : "Mumbai"},
                   {"height" : 2, "weight" : 24, "age" : 25, "city" : "Delhi"},
                  {"height" : 3, "weight" : 25, "age" : 26, "city" : "Kolkata"},
                  {"height" : 4, "weight" : 26, "age" : 27, "city" : "Chennai"},
                  {"height" : 5, "weight" : 27, "age" : 28, "city" : "Panipat"}])
dataframe
# Out:
#    height  weight  age     city
# 0       1      23   24   Mumbai
# 1       2      24   25    Delhi
# 2       3      25   26  Kolkata
# 3       4      26   27  Chennai
# 4       5      27   28  Panipat

# %%
dataframe.iloc[2:5, :]
# Out:
#    height  weight  age     city
# 2       3      25   26  Kolkata
# 3       4      26   27  Chennai
# 4       5      27   28  Panipat

# %%
dataframe.loc[2:5, :]
# Out:
#    height  weight  age     city
# 2       3      25   26  Kolkata
# 3       4      26   27  Chennai
# 4       5      27   28  Panipat

# %%
dataframe.loc[:, ["height", "weight", "age", "city"]]
# Out:
#    height  weight  age     city
# 0       1      23   24   Mumbai
# 1       2      24   25    Delhi
# 2       3      25   26  Kolkata
# 3       4      26   27  Chennai
# 4       5      27   28  Panipat
