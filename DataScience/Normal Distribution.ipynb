# %%
# Explore two parameters that you select with
# respect to the type (which might also be the sample size (n) which is not a classical parameter); decide on
# reasonable values for both parameters; generate corresponding random values; and explore the generated values
# visually in a two-dimensional grid of histograms with respect to the parameters.

# %%
# Normal Distribution 
# The two parameters are Mean and Standard Deviation

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(15,15))
ax = ax.ravel()
scale = 40
for i in range(16):
    ax[i].hist(np.random.normal(loc=i, scale =scale, size=(100000)),bins=85)
    ax[i].set_xlabel('mean ={} and sd ={}'.format(i,scale))
    ax[i].set_ylabel('Frequency')
    scale = scale + 10
plt.show()
