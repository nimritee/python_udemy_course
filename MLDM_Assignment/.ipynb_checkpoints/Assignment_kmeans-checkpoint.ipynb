# %%
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df  = pd.read_csv("Categorical.csv")

# %%
x = 'Longitude'
y = 'Latitude'

df = df.loc[:,[x,y]]

kmeans = KMeans(n_clusters=4)
kmeans.fit(df)
print(kmeans.cluster_centers_)
print(kmeans.labels_)


plt.scatter(df[x], df[y], c=kmeans.labels_, cmap='rainbow', alpha=0.5, edgecolor='black')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black',marker='+')
# Out:
# [[  7.66363177  38.10108667]
#  [127.73186917   8.79492262]
#  [-82.03484643   5.55229685]
#  [ 44.00131334   8.13168591]]
# [2 3 3 2 0 0 0 3 2 3 2 3 1 3 2 1 0 3 3 0 0 0 1 0 3 2 2 0 2 0 2 2 2 2 2 1 1
#  3 3 0 2 1 0 3 3 3 2 2 3 0 2 2 2 2 0 0 0 0 3 2 0 2 0 2 3 3 0 0 3 0 1 2 0 0
#  1 3 0 3 0 0 0 0 0 3 0 2 0 2 1 2 1 3 2 0 2 0 1 0 3 1 3 0 3 3 0 3 0 2 0 3 1
#  3 3 3 3 1 2 2 1 0 3 1 3 0 0 2 0 3 3 0 0 0 1 2 0 0 0 3 3 2 1 0 0 0 1 0 1 1
#  3 0 2 3 3 1 3 1 0 1 0 2 2 0 0 3 1 1 3 3 2 2 2 1 1 1 0 2 1 0 2 3 2 3 0 1 3
#  0 3 3 3 0 1 2 0 1 0 2 0 3 3 2 0 0 2 0 0 0 3 2 3 3 2 0 0 1 3 3 1 2 2 0 0 1
#  3 3 0 2 2 3 0 2 2 2 2 1 1 2 2 3 3 3 3]
